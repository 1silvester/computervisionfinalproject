# %% [markdown]
# <a href="https://colab.research.google.com/github/1silvester/computervisionfinalproject/blob/main/happy_house_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, h5py 
import cv2
import matplotlib.pyplot as plt 
from google.colab import files, drive
import numpy as np
import tensorflow as tf
import keras_preprocessing 
from keras_preprocessing import image
from keras_preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score
import matplotlib.image as matimg

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
root_path_train = 'gdrive/My Drive/final_project/happy_house_dataset/archive/train_happy.h5'
root_path_test = 'gdrive/My Drive/final_project/happy_house_dataset/archive/test_happy.h5'

# %%
def load_happy_dataset(training_data_set, testing_data_set):
  train_data_set = h5py.File(root_path_train)
  data_x_axis = np.array(train_data_set['train_set_x'][:])
  data_y_axis = np.array(train_data_set['train_set_y'][:])

  test_data_set = h5py.File(root_path_test)
  test_data_x_axis = np.array(test_data_set['test_set_x'][:])
  test_data_y_axis = np.array(test_data_set['test_set_y'][:])

  print("before",tf.shape(data_y_axis).numpy())
  print("before",tf.shape(data_x_axis).numpy())
  print("before",tf.shape(test_data_y_axis).numpy())
  print("before",tf.shape(test_data_x_axis).numpy())

  data_y_axis = data_y_axis.reshape((1, data_x_axis.shape[0]))
  test_data_y_axis = test_data_y_axis.reshape(1, test_data_y_axis.shape[0])

  print("after ",tf.shape(data_y_axis).numpy())
  print("after ",tf.shape(data_x_axis).numpy())
  print("after ",tf.shape(test_data_y_axis).numpy())
  print("after ",tf.shape(test_data_x_axis).numpy())

  return data_x_axis, data_y_axis, test_data_x_axis, test_data_y_axis

# %%
processed_data_set = load_happy_dataset(root_path_train, root_path_test)
# Out:
# before [600]
# before [600  64  64   3]
# before [150]
# before [150  64  64   3]
# after  [  1 600]
# after  [600  64  64   3]
# after  [  1 150]
# after  [150  64  64   3]

# %%
numrows = 4
numcols = 4
pictureindex = 0

fig = plt.gcf()
fig.set_size_inches(numcols * 4, numrows * 4)

pictureindex += 16

first_picture = [image_ for image_ in processed_data_set[0][pictureindex-16: pictureindex]]


for i, image in enumerate(first_picture):

  subplot = plt.subplot(numrows, numcols, i+1)
  plt.imshow(image)

plt.show()
# Out:
# 1

# %% [markdown]
# ##Need to talk about the data here, mostly only white men in there 20s-30s, 1 dimensional only smiling and not smiling. 2d images

# %%
trainingdatax, trainingdatay, testingdatax, testingdatay = processed_data_set

# %%
def image_data_as_array(training_data, testing_data):
  training_image_array = []
  test_image_array = []
  for train_array in training_data:
    traingrayimage = cv2.cvtColor(train_array, cv2.COLOR_RGB2GRAY)
    training_image_array.append(traingrayimage)

  training_image_array = np.array(training_image_array)

  for test_image in testing_data:
    testgrayimage = cv2.cvtColor(test_image, cv2.COLOR_RGB2GRAY)
    test_image_array.append(testgrayimage)

  test_image_array = np.array(test_image_array)

  return training_image_array, test_image_array

# %%
array_data = image_data_as_array(processed_data_set[0], processed_data_set[2])

# %%
x_axis_training_data = array_data[0]
y_axis_training_data = processed_data_set[1]
x_axis_test_data = array_data[1]
y_axis_test_data = processed_data_set[3]

print(x_axis_training_data.shape, y_axis_training_data.shape)
print(x_axis_test_data.shape , y_axis_test_data.shape)
# Out:
# (600, 64, 64) (1, 600)
# (150, 64, 64) (1, 150)

# %% [markdown]
# plotting what the images look like here

# %%
x_axis_training_data = x_axis_training_data.reshape((-1, 64, 64, 1))
x_axis_test_data = x_axis_test_data.reshape((-1, 64, 64, 1))

# %% [markdown]
# #Talk about reshaping data and why you did it

# %%
print(y_axis_training_data.shape)

y_axis_training_data = np.moveaxis(y_axis_training_data, -1, 0)
# Out:
# (1, 600)

# %%
print(y_axis_training_data.shape)
# Out:
# (600, 1)

# %%
print(x_axis_training_data.shape, y_axis_training_data.shape)

print(type(x_axis_training_data), type(x_axis_test_data))
print(type(y_axis_test_data), type(y_axis_training_data))
# Out:
# (600, 64, 64, 1) (600, 1)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
y_axis_test_data = np.moveaxis(y_axis_test_data, -1, 0)
print(y_axis_test_data.shape)
# Out:
# (150, 1)

# %%
training_datagen = ImageDataGenerator(
                    samplewise_center=True,
                    samplewise_std_normalization=True,
                    zoom_range=[0.6, 1.1],
                    rotation_range=20,
                    width_shift_range=0.2,
                    height_shift_range=0.2,
                    horizontal_flip=True,
                    )

testing_datagen = ImageDataGenerator(
                samplewise_center=True,
                samplewise_std_normalization=True)

training_generator = training_datagen.flow(x_axis_training_data, y_axis_training_data, batch_size=18, shuffle=True)
testing_generator = testing_datagen.flow(x_axis_test_data, y_axis_test_data, batch_size=18, shuffle=False)

# %%
def create_model():

  model = tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(16, (3,3), activation='relu', padding='same', input_shape=(64,64,1)),
                                    tf.keras.layers.MaxPooling2D(2,2),
                                    tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
                                    tf.keras.layers.MaxPooling2D(2,2),
                                    tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
                                    tf.keras.layers.MaxPooling2D(2,2),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dropout(0.3),
                                    tf.keras.layers.Dense(512, activation='relu'),
                                    tf.keras.layers.Dense(1, activation='sigmoid')
    ])
  return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 64, 64, 16)        160
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               2097664
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 2,121,473
# Trainable params: 2,121,473
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# #why these parameters

# %%
model_save_name = 'happy_house_training.pt'
path = F"gdrive/My Drive/final_project/models/happyhousedataset/{model_save_name}"

history = model.fit(training_generator, epochs=50, validation_data=testing_generator, callbacks=[
                                                                                                 tf.keras.callbacks.ModelCheckpoint(path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1),
                                                                                                 tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.3, patience=8, verbose=1, mode='auto', min_lr=0.001)
])
# Out:
# Epoch 1/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4621 - accuracy: 0.7567 - val_loss: 0.4573 - val_accuracy: 0.7667
#
# Epoch 00001: val_accuracy improved from -inf to 0.76667, saving model to gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt
# INFO:tensorflow:Assets written to: gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt/assets
# Epoch 2/50
# 34/34 [==============================] - 4s 116ms/step - loss: 0.4420 - accuracy: 0.7767 - val_loss: 0.3899 - val_accuracy: 0.7800
#
# Epoch 00002: val_accuracy improved from 0.76667 to 0.78000, saving model to gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt
# INFO:tensorflow:Assets written to: gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt/assets
# Epoch 3/50
# 34/34 [==============================] - 4s 115ms/step - loss: 0.4734 - accuracy: 0.7533 - val_loss: 0.5473 - val_accuracy: 0.7867
#
# Epoch 00003: val_accuracy improved from 0.78000 to 0.78667, saving model to gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt
# INFO:tensorflow:Assets written to: gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt/assets
# Epoch 4/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4895 - accuracy: 0.7450 - val_loss: 0.4598 - val_accuracy: 0.8067
#
# Epoch 00004: val_accuracy improved from 0.78667 to 0.80667, saving model to gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt
# INFO:tensorflow:Assets written to: gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt/assets
# Epoch 5/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4793 - accuracy: 0.7483 - val_loss: 0.5037 - val_accuracy: 0.7800
#
# Epoch 00005: val_accuracy did not improve from 0.80667
# Epoch 6/50
# 34/34 [==============================] - 4s 111ms/step - loss: 0.4939 - accuracy: 0.7400 - val_loss: 0.3775 - val_accuracy: 0.8133
#
# Epoch 00006: val_accuracy improved from 0.80667 to 0.81333, saving model to gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt
# INFO:tensorflow:Assets written to: gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt/assets
# Epoch 7/50
# 34/34 [==============================] - 4s 110ms/step - loss: 0.4827 - accuracy: 0.7533 - val_loss: 0.5013 - val_accuracy: 0.7733
#
# Epoch 00007: val_accuracy did not improve from 0.81333
# Epoch 8/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4627 - accuracy: 0.7550 - val_loss: 0.4952 - val_accuracy: 0.7133
#
# Epoch 00008: val_accuracy did not improve from 0.81333
# Epoch 9/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4748 - accuracy: 0.7700 - val_loss: 0.5038 - val_accuracy: 0.7867
#
# Epoch 00009: val_accuracy did not improve from 0.81333
# Epoch 10/50
# 34/34 [==============================] - 4s 112ms/step - loss: 0.4707 - accuracy: 0.7583 - val_loss: 0.4013 - val_accuracy: 0.8333
#
# Epoch 00010: val_accuracy improved from 0.81333 to 0.83333, saving model to gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt
# INFO:tensorflow:Assets written to: gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt/assets
# Epoch 11/50
# 34/34 [==============================] - 4s 111ms/step - loss: 0.4713 - accuracy: 0.7667 - val_loss: 0.4129 - val_accuracy: 0.7800
#
# Epoch 00011: val_accuracy did not improve from 0.83333
# Epoch 12/50
# 34/34 [==============================] - 4s 116ms/step - loss: 0.4688 - accuracy: 0.7650 - val_loss: 0.3638 - val_accuracy: 0.8000
#
# Epoch 00012: val_accuracy did not improve from 0.83333
# Epoch 13/50
# 34/34 [==============================] - 4s 112ms/step - loss: 0.4845 - accuracy: 0.7567 - val_loss: 0.4814 - val_accuracy: 0.7133
#
# Epoch 00013: val_accuracy did not improve from 0.83333
# Epoch 14/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4501 - accuracy: 0.7617 - val_loss: 0.4789 - val_accuracy: 0.7867
#
# Epoch 00014: val_accuracy did not improve from 0.83333
# Epoch 15/50
# 34/34 [==============================] - 4s 112ms/step - loss: 0.4818 - accuracy: 0.7450 - val_loss: 0.3952 - val_accuracy: 0.7533
#
# Epoch 00015: val_accuracy did not improve from 0.83333
# Epoch 16/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4676 - accuracy: 0.7533 - val_loss: 0.4074 - val_accuracy: 0.7600
#
# Epoch 00016: val_accuracy did not improve from 0.83333
# Epoch 17/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4122 - accuracy: 0.7917 - val_loss: 0.4077 - val_accuracy: 0.7600
#
# Epoch 00017: val_accuracy did not improve from 0.83333
# Epoch 18/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4711 - accuracy: 0.7633 - val_loss: 0.3615 - val_accuracy: 0.8333
#
# Epoch 00018: val_accuracy did not improve from 0.83333
# Epoch 19/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4411 - accuracy: 0.7750 - val_loss: 0.3746 - val_accuracy: 0.7667
#
# Epoch 00019: val_accuracy did not improve from 0.83333
# Epoch 20/50
# 34/34 [==============================] - 4s 112ms/step - loss: 0.4351 - accuracy: 0.7800 - val_loss: 0.5148 - val_accuracy: 0.7533
#
# Epoch 00020: val_accuracy did not improve from 0.83333
# Epoch 21/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4618 - accuracy: 0.7817 - val_loss: 0.5660 - val_accuracy: 0.7333
#
# Epoch 00021: val_accuracy did not improve from 0.83333
# Epoch 22/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4329 - accuracy: 0.7883 - val_loss: 0.8221 - val_accuracy: 0.6733
#
# Epoch 00022: val_accuracy did not improve from 0.83333
# Epoch 23/50
# 34/34 [==============================] - 4s 112ms/step - loss: 0.4610 - accuracy: 0.7617 - val_loss: 0.4683 - val_accuracy: 0.7400
#
# Epoch 00023: val_accuracy did not improve from 0.83333
# Epoch 24/50
# 34/34 [==============================] - 4s 111ms/step - loss: 0.4056 - accuracy: 0.7900 - val_loss: 0.3903 - val_accuracy: 0.8067
#
# Epoch 00024: val_accuracy did not improve from 0.83333
# Epoch 25/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4363 - accuracy: 0.7867 - val_loss: 0.3879 - val_accuracy: 0.7800
#
# Epoch 00025: val_accuracy did not improve from 0.83333
# Epoch 26/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4500 - accuracy: 0.7483 - val_loss: 0.8434 - val_accuracy: 0.7200
#
# Epoch 00026: val_accuracy did not improve from 0.83333
# Epoch 27/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4360 - accuracy: 0.7817 - val_loss: 0.4295 - val_accuracy: 0.7667
#
# Epoch 00027: val_accuracy did not improve from 0.83333
# Epoch 28/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4646 - accuracy: 0.7783 - val_loss: 0.5320 - val_accuracy: 0.7333
#
# Epoch 00028: val_accuracy did not improve from 0.83333
# Epoch 29/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4507 - accuracy: 0.7883 - val_loss: 0.4643 - val_accuracy: 0.7800
#
# Epoch 00029: val_accuracy did not improve from 0.83333
# Epoch 30/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4518 - accuracy: 0.7733 - val_loss: 0.3895 - val_accuracy: 0.7800
#
# Epoch 00030: val_accuracy did not improve from 0.83333
# Epoch 31/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4361 - accuracy: 0.7700 - val_loss: 0.3363 - val_accuracy: 0.8467
#
# Epoch 00031: val_accuracy improved from 0.83333 to 0.84667, saving model to gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt
# INFO:tensorflow:Assets written to: gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt/assets
# Epoch 32/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4472 - accuracy: 0.7817 - val_loss: 0.3480 - val_accuracy: 0.8000
#
# Epoch 00032: val_accuracy did not improve from 0.84667
# Epoch 33/50
# 34/34 [==============================] - 4s 115ms/step - loss: 0.3997 - accuracy: 0.8050 - val_loss: 0.3804 - val_accuracy: 0.7800
#
# Epoch 00033: val_accuracy did not improve from 0.84667
# Epoch 34/50
# 34/34 [==============================] - 4s 115ms/step - loss: 0.4073 - accuracy: 0.8100 - val_loss: 0.4495 - val_accuracy: 0.7533
#
# Epoch 00034: val_accuracy did not improve from 0.84667
# Epoch 35/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4194 - accuracy: 0.8133 - val_loss: 0.3977 - val_accuracy: 0.8333
#
# Epoch 00035: val_accuracy did not improve from 0.84667
# Epoch 36/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4671 - accuracy: 0.7600 - val_loss: 0.4884 - val_accuracy: 0.7200
#
# Epoch 00036: val_accuracy did not improve from 0.84667
# Epoch 37/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4026 - accuracy: 0.8150 - val_loss: 0.2958 - val_accuracy: 0.8533
#
# Epoch 00037: val_accuracy improved from 0.84667 to 0.85333, saving model to gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt
# INFO:tensorflow:Assets written to: gdrive/My Drive/final_project/models/happyhousedataset/happy_house_training.pt/assets
# Epoch 38/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4670 - accuracy: 0.7733 - val_loss: 0.3441 - val_accuracy: 0.8200
#
# Epoch 00038: val_accuracy did not improve from 0.85333
# Epoch 39/50
# 34/34 [==============================] - 4s 112ms/step - loss: 0.4203 - accuracy: 0.8100 - val_loss: 0.3856 - val_accuracy: 0.7667
#
# Epoch 00039: val_accuracy did not improve from 0.85333
# Epoch 40/50
# 34/34 [==============================] - 4s 115ms/step - loss: 0.4357 - accuracy: 0.7733 - val_loss: 0.3919 - val_accuracy: 0.7467
#
# Epoch 00040: val_accuracy did not improve from 0.85333
# Epoch 41/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4197 - accuracy: 0.8000 - val_loss: 0.3745 - val_accuracy: 0.8000
#
# Epoch 00041: val_accuracy did not improve from 0.85333
# Epoch 42/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4178 - accuracy: 0.8233 - val_loss: 0.3417 - val_accuracy: 0.7733
#
# Epoch 00042: val_accuracy did not improve from 0.85333
# Epoch 43/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4097 - accuracy: 0.8100 - val_loss: 0.4844 - val_accuracy: 0.7467
#
# Epoch 00043: val_accuracy did not improve from 0.85333
# Epoch 44/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4202 - accuracy: 0.8117 - val_loss: 0.5826 - val_accuracy: 0.7200
#
# Epoch 00044: val_accuracy did not improve from 0.85333
# Epoch 45/50
# 34/34 [==============================] - 4s 112ms/step - loss: 0.4332 - accuracy: 0.8150 - val_loss: 0.4373 - val_accuracy: 0.7333
#
# Epoch 00045: val_accuracy did not improve from 0.85333
# Epoch 46/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4013 - accuracy: 0.7983 - val_loss: 0.5772 - val_accuracy: 0.7067
#
# Epoch 00046: val_accuracy did not improve from 0.85333
# Epoch 47/50
# 34/34 [==============================] - 4s 113ms/step - loss: 0.4536 - accuracy: 0.7767 - val_loss: 0.4765 - val_accuracy: 0.7000
#
# Epoch 00047: val_accuracy did not improve from 0.85333
# Epoch 48/50
# 34/34 [==============================] - 4s 114ms/step - loss: 0.4074 - accuracy: 0.8067 - val_loss: 0.3307 - val_accuracy: 0.8533
#
# Epoch 00048: val_accuracy did not improve from 0.85333
# Epoch 49/50
# 34/34 [==============================] - 4s 115ms/step - loss: 0.4296 - accuracy: 0.7883 - val_loss: 0.3223 - val_accuracy: 0.8467
#
# Epoch 00049: val_accuracy did not improve from 0.85333
# Epoch 50/50
# 34/34 [==============================] - 4s 115ms/step - loss: 0.4076 - accuracy: 0.8033 - val_loss: 0.3270 - val_accuracy: 0.8133
#
# Epoch 00050: val_accuracy did not improve from 0.85333

# %%
def plot_history_data(history_data):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'r', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend(loc=0)
  plt.figure()

  plt.plot(epochs, loss, 'ro', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  return plt.show()

# %%
plot_history_data(history)

# %%
image_input = x_axis_test_data.copy().astype(np.float64)
image_input -= np.mean(x_axis_test_data, keepdims=True)
image_input /= (np.std(x_axis_test_data, keepdims=True))

classa = model.predict(image_input)

predicted_emotion = (classa > 0.5).astype(np.int)
print('accuracy: %s'% accuracy_score(y_axis_test_data,predicted_emotion))
# Out:
# accuracy: 0.7

# %% [markdown]
# #test further with more images and a range of pictures. You will need to process the images to match the input the model expects including gray scale. also try and do a live webcam demo
